# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import seaborn as sns
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import mlab
from matplotlib.ticker import FuncFormatter
matplotlib.style.use('ggplot')
import sqlite3 
import warnings
warnings.filterwarnings('ignore')
pd.options.mode.chained_assignment = None

# %%
url = 'https://data.ny.gov/api/views/bjcb-yee3/rows.csv?accessType=DOWNLOAD'
df = pd.read_csv(url, nrows=1000, sep = ',',header = 0)
df.head()
# Out:
#      C/A  Unit       SCP        Station Line Name Division        Date  \
# 0  N339A  R114  00-03-00   PARSONS BLVD         F      IND  12/29/2017
# 1  R601A  R108  02-00-04   BOROUGH HALL     2345R      IRT  12/23/2017
# 2   N405  R239  00-03-00  GREENPOINT AV         G      IND  12/28/2017
# 3   N700  R570  00-03-03    72 ST-2 AVE         Q      IND  12/28/2017
# 4   J037  R009  00-00-02         121 ST        JZ      BMT  12/25/2017
#
#        Time Description  Entries  \
# 0  07:00:00     REGULAR   880265
# 1  03:00:00     REGULAR  7806453
# 2  07:00:00     REGULAR      973
# 3  00:00:00     REGULAR  1397123
# 4  15:00:00     REGULAR   754018
#
#    Exits
# 0                                             885883
# 1                                            7862828
# 2                                                  0
# 3                                             246622
# 4                                             265570
